# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\niyas\Downloads\Github\Consumer Financial Complaints\data\Consumer Financial Complaints Dataset.xlsx")

# %%
df.head(2)
# Out:
#    Complaint ID Submitted via  Date submitted  Date received State  \
# 0       4848023      Referral           44493          44496    NY
# 1       3621464           Web           43945          43945    FL
#
#    State_Latitude  State_Longitude  \
# 0       42.165726       -74.948051
# 1       27.766279       -81.686783
#
#                                              Product  \
# 0                                           Mortgage
# 1  Money transfer, virtual currency, or money ser...
#
#                   Sub-product  \
# 0  Conventional home mortgage
# 1   Refund anticipation check
#
#                                                Issue Sub-issue  \
# 0  Applying for a mortgage or refinancing an exis...       NaN
# 1                               Lost or stolen check       NaN
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1  Company has responded to the consumer and the ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62516 entries, 0 to 62515
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Complaint ID                  62516 non-null  int64
#  1   Submitted via                 62516 non-null  object
#  2   Date submitted                62516 non-null  int64
#  3   Date received                 62516 non-null  int64
#  4   State                         62516 non-null  object
#  5   State_Latitude                62516 non-null  float64
#  6   State_Longitude               62516 non-null  float64
#  7   Product                       62516 non-null  object
#  8   Sub-product                   62509 non-null  object
#  9   Issue                         62516 non-null  object
#  10  Sub-issue                     51658 non-null  object
#  11  Company public response       60341 non-null  object
# ...

# %%
df.describe()
# Out:
#        Complaint ID  Date submitted  Date received  State_Latitude  \
# count  6.251600e+04    62516.000000   62516.000000    62516.000000
# mean   4.512642e+06    44159.671700   44160.896586       36.886985
# std    1.442917e+06      675.231304     675.085479        5.016981
# min    2.471340e+06    42856.000000   42856.000000       21.094318
# 25%    3.254020e+06    43607.000000   43613.000000       33.729759
# 50%    4.178582e+06    44257.000000   44258.000000       36.116203
# 75%    5.771284e+06    44756.000000   44757.000000       40.349457
# max    7.458912e+06    45166.000000   45166.000000       61.370716
#
#        State_Longitude  Company_Response_Date  Response_Time_Days
# count     62516.000000           62516.000000        62516.000000
# mean        -93.963607           44174.760173           15.088473
# std          18.467921             675.287997            8.913996
# min        -157.498337           42857.000000            0.000000
# ...

# %%
df.shape
# Out:
# (62516, 19)

# %%
df['Complaint ID'].count().sum()
# Out:
# np.int64(62516)

# %%
df.isnull().sum()
# Out:
# Complaint ID                        0
# Submitted via                       0
# Date submitted                      0
# Date received                       0
# State                               0
# State_Latitude                      0
# State_Longitude                     0
# Product                             0
# Sub-product                         7
# Issue                               0
# Sub-issue                       10858
# Company public response          2175
# Company response to consumer        0
# Timely response?                 1494
# Census_Region                       0
# Census_Division                     0
# Company_Response_Date               0
# Company_ID_1081                     0
# Response_Time_Days                  0
# dtype: int64

# %%
origin_date = pd.to_datetime('1899-12-30')
date_columns = ['Date submitted', 'Date received', 'Company_Response_Date']

for col in date_columns:
    df[col] = origin_date + pd.to_timedelta(df[col], unit='D')

# %%
df.head()
# Out:
#    Complaint ID Submitted via Date submitted Date received State  \
# 0       4848023      Referral     2021-10-24    2021-10-27    NY
# 1       3621464           Web     2020-04-24    2020-04-24    FL
# 2       5818349           Web     2022-07-27    2022-07-27    CA
# 3       7233015      Referral     2023-07-10    2023-07-11    CA
# 4       5820224      Referral     2022-07-27    2022-07-28    VA
#
#    State_Latitude  State_Longitude  \
# 0       42.165726       -74.948051
# 1       27.766279       -81.686783
# 2       36.116203      -119.681564
# 3       36.116203      -119.681564
# 4       37.769337       -78.169968
#
#                                              Product  \
# 0                                           Mortgage
# 1  Money transfer, virtual currency, or money ser...
# 2  Credit reporting, credit repair services, or o...
# 3                        Credit card or prepaid card
# 4                        Credit card or prepaid card
#
# ...

# %%
df = df.fillna({
    'Sub-product' : 'Not Specified' ,
    'Sub-issue' : 'Not Specified' ,
    'Company public response' : 'Not Specified' ,
    'Timely response?' : 'Not Specified'
})

# %%
df.head(1)
# Out:
#    Complaint ID Submitted via Date submitted Date received State  \
# 0       4848023      Referral     2021-10-24    2021-10-27    NY
#
#    State_Latitude  State_Longitude   Product                 Sub-product  \
# 0       42.165726       -74.948051  Mortgage  Conventional home mortgage
#
#                                                Issue      Sub-issue  \
# 0  Applying for a mortgage or refinancing an exis...  Not Specified
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
#
#   Company response to consumer Timely response? Census_Region  \
# 0      Closed with explanation              Yes     Northeast
#
#    Census_Division Company_Response_Date Company_ID_1081  Response_Time_Days
# 0  Middle Atlantic            2021-10-30       COMP-0820                   6

# %%
df.isnull().sum()
# Out:
# Complaint ID                    0
# Submitted via                   0
# Date submitted                  0
# Date received                   0
# State                           0
# State_Latitude                  0
# State_Longitude                 0
# Product                         0
# Sub-product                     0
# Issue                           0
# Sub-issue                       0
# Company public response         0
# Company response to consumer    0
# Timely response?                0
# Census_Region                   0
# Census_Division                 0
# Company_Response_Date           0
# Company_ID_1081                 0
# Response_Time_Days              0
# dtype: int64

# %%
df_company = pd.read_excel(r"C:\Users\niyas\Downloads\Github\Consumer Financial Complaints\data\Consumer Financial Complaints Dataset.xlsx", 
                           sheet_name='Company')

# %%
df_company.shape
# Out:
# (1081, 9)

# %%
df_company.head()
# Out:
#   Company_ID_1081  Market_Share_Percent  Reputation_Score Enforcement_History  \
# 0       COMP-0001                0.0385                75                  No
# 1       COMP-0002                0.0781                82                  No
# 2       COMP-0003                0.0169                63                  No
# 3       COMP-0004                0.0271                95                  No
# 4       COMP-0005                0.0273                69                  No
#
#   Company_Size_Tier  Complaint_Count  Timely_Response_Rate  \
# 0             Small               50              0.900000
# 1             Small               63              0.920635
# 2             Small               61              0.967213
# 3             Small               56              0.946429
# 4             Small               70              0.957143
#
#    Avg_Response_Time_Days  Complaints_per_1pct_Share
# 0               14.600000                  1298.7013
# ...

# %%
df_merged = pd.merge(df, df_company, on='Company_ID_1081', how='left')

# %%
df_merged.head(1)
# Out:
#    Complaint ID Submitted via Date submitted Date received State  \
# 0       4848023      Referral     2021-10-24    2021-10-27    NY
#
#    State_Latitude  State_Longitude   Product                 Sub-product  \
# 0       42.165726       -74.948051  Mortgage  Conventional home mortgage
#
#                                                Issue  ... Company_ID_1081  \
# 0  Applying for a mortgage or refinancing an exis...  ...       COMP-0820
#
#   Response_Time_Days Market_Share_Percent Reputation_Score  \
# 0                  6               0.0099               92
#
#   Enforcement_History Company_Size_Tier Complaint_Count Timely_Response_Rate  \
# 0                  No             Small              56             0.910714
#
#    Avg_Response_Time_Days  Complaints_per_1pct_Share
# 0                  12.875                  5656.5657
#
# [1 rows x 27 columns]

# %%
df_merged.shape
# Out:
# (62516, 27)

# %%
df_merged.to_csv('cleaned_financial_complaints.csv', index=False)
